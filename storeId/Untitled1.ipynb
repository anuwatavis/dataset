# %%
import requests

# %%
import bs4

# %%
r = requests.get("https://www.lazada.co.th/products/45l-i960894279-s2040938649.html?spm=a2o4m.10453683.0.0.1d7e16aa6Wclr2&mp=3") 
r.text
# Out:
# '\r\n<!DOCTYPE HTML>\n<html xmlns:wormhole="http://www.w3.org/1999/xhtml"\n>\n<head>\n    <title>หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ | Lazada.co.th</title>\n    <meta name="description" content="ซื้อสินค้า หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ ออนไลน์กับลาซาด้า รับโปรโมชั่นและส่วนลดพิเศษ และ ฟรีค่าจัดส่ง"/>\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no"/>\n    <meta name="aplus-auto-exp" content=\'[{"filter":"exp-tracking=suggest-official-store","logkey":"/lzdse.result.os_impr","props":["href"],"tag":"a"}]\' />\n    <meta name="data-spm" content="a2o4m"/>\n    <meta name="robots" content="index,follow" />\n\n    <link rel="stylesheet" href="//laz-g-cdn.alicdn.com/lzd/assets/0.0.7/dpl-buyeruikit/2.0.1/next-noreset-1.css">\n    <link rel="s
# ...

# %%
html_page = bs4.BeautifulSoup(r.text, "html.parser")
print(html_page)
# Out:
# <!DOCTYPE HTML>
#
# <html xmlns:wormhole="http://www.w3.org/1999/xhtml">
# <head>
# <title>หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ | Lazada.co.th</title>
# <meta content="ซื้อสินค้า หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ ออนไลน์กับลาซาด้า รับโปรโมชั่นและส่วนลดพิเศษ และ ฟรีค่าจัดส่ง" name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content='[{"filter":"exp-tracking=suggest-official-store","logkey":"/lzdse.result.os_impr","props":["href"],"tag":"a"}]' name="aplus-auto-exp"/>
# <meta content="a2o4m" name="data-spm"/>
# <meta content="index,follow" name="robots"/>
# <link href="//laz-g-cdn.alicdn.com/lzd/assets/0.0.7/dpl-buyeruikit/2.0.1/next-noreset-1.css" rel="stylesheet"/>
# ...

# %%
type(html_page)
# Out:
# bs4.BeautifulSoup

# %%
print(html_page.prettify())
# Out:
# <!DOCTYPE HTML>
# <html xmlns:wormhole="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ | Lazada.co.th
#   </title>
#   <meta content="ซื้อสินค้า หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ ออนไลน์กับลาซาด้า รับโปรโมชั่นและส่วนลดพิเศษ และ ฟรีค่าจัดส่ง" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content='[{"filter":"exp-tracking=suggest-official-store","logkey":"/lzdse.result.os_impr","props":["href"],"tag":"a"}]' name="aplus-auto-exp"/>
#   <meta content="a2o4m" name="data-spm"/>
#   <meta content="index,follow" name="robots"/>
#   <link href="//laz-g-cdn.alicdn.com/lzd/assets/0.0.7/dpl-buyeruikit/2.0.1/next-noreset-1.css" rel="stylesheet"/>
# ...

# %%
selector = 'div.seller-info-value.rating-positive'

# %%
price = html_page.select_one(selector)
price

# %%
print(price)
# Out:
# None

# %%
print(html_page)
# Out:
# <!DOCTYPE HTML>
#
# <html xmlns:wormhole="http://www.w3.org/1999/xhtml">
# <head>
# <title>หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ | Lazada.co.th</title>
# <meta content="ซื้อสินค้า หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ ออนไลน์กับลาซาด้า รับโปรโมชั่นและส่วนลดพิเศษ และ ฟรีค่าจัดส่ง" name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content='[{"filter":"exp-tracking=suggest-official-store","logkey":"/lzdse.result.os_impr","props":["href"],"tag":"a"}]' name="aplus-auto-exp"/>
# <meta content="a2o4m" name="data-spm"/>
# <meta content="index,follow" name="robots"/>
# <link href="//laz-g-cdn.alicdn.com/lzd/assets/0.0.7/dpl-buyeruikit/2.0.1/next-noreset-1.css" rel="stylesheet"/>
# ...

# %%
type(html_page)
# Out:
# bs4.BeautifulSoup

# %%
print(html_page.prettify())
# Out:
# <!DOCTYPE HTML>
# <html xmlns:wormhole="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ | Lazada.co.th
#   </title>
#   <meta content="ซื้อสินค้า หม้อทอดอากาศสำหรับใช้ในบ้านความจุขนาดใหญ่ 4.5Lหม้อทอดไร้น้ำมันไร้ควันหม้อทอดไฟฟ้าอัตโนมัติหม้อทำไก่ทอดมันฝรั่งทอดอัติโนมัติ ออนไลน์กับลาซาด้า รับโปรโมชั่นและส่วนลดพิเศษ และ ฟรีค่าจัดส่ง" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content='[{"filter":"exp-tracking=suggest-official-store","logkey":"/lzdse.result.os_impr","props":["href"],"tag":"a"}]' name="aplus-auto-exp"/>
#   <meta content="a2o4m" name="data-spm"/>
#   <meta content="index,follow" name="robots"/>
#   <link href="//laz-g-cdn.alicdn.com/lzd/assets/0.0.7/dpl-buyeruikit/2.0.1/next-noreset-1.css" rel="stylesheet"/>
# ...

# %%
soup = BeautifulSoup(r.content, "html.parser")
data = soup.find("script ")
print(data)
# Out:
# None
